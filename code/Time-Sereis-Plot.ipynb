# %%
import pandas as pd

data = pd.read_csv(r"G:\Youtube\training_model\plot\ratio.csv")
data
# Out:
#      Unnamed: 0        Date     Total  Fox News  Breitbart  MSNBC  NBC News  \
# 0             0  2020-01-22  0.000000       NaN        NaN    NaN       NaN
# 1             1  2020-01-23  0.166667       NaN        NaN    NaN  0.162791
# 2             2  2020-01-24  0.135266       NaN        NaN    NaN  0.152941
# 3             3  2020-01-25  0.130719       NaN        NaN    NaN  0.129252
# 4             4  2020-01-26  0.130872       NaN        NaN    NaN  0.133106
# ..          ...         ...       ...       ...        ...    ...       ...
# 322         322  2020-12-09  0.008065       0.2        NaN    0.0  0.000000
# 323         323  2020-12-10  0.000000       0.0        NaN    0.0  0.000000
# 324         324  2020-12-11  0.020833       0.0        NaN    0.0  0.000000
# 325         325  2020-12-12  0.000000       NaN        NaN    NaN       NaN
# 326         326  2020-12-13  0.000000       NaN        NaN    NaN       NaN
#
# ...

# %%
total_data = data[["Date","Total"]]
total_data
# Out:
#            Date     Total
# 0    2020-01-22  0.000000
# 1    2020-01-23  0.166667
# 2    2020-01-24  0.135266
# 3    2020-01-25  0.130719
# 4    2020-01-26  0.130872
# ..          ...       ...
# 322  2020-12-09  0.008065
# 323  2020-12-10  0.000000
# 324  2020-12-11  0.020833
# 325  2020-12-12  0.000000
# 326  2020-12-13  0.000000
#
# [327 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

dr = pd.date_range('02-01-2020', '07-01-2020', freq='1D')

y = pd.Series(range(len(dr))) ** 2

fig, ax = plt.subplots()
ax.plot(dr, y)

ax.annotate('1st Lockdown',
            xy=(dr[50], y[50]), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 100), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->"), #style of the arrow
            ha='center') #center the text horizontally

ax.annotate('2nd Lockdown',
            xy=(dr[100], y[100]), xycoords='data',
            xytext=(0, 100), textcoords='offset points',
            arrowprops=dict(arrowstyle="->"), ha='center')
# Out:
# Text(0, 100, '2nd Lockdown')

# %%
dr
# Out:
# DatetimeIndex(['2020-02-01', '2020-02-02', '2020-02-03', '2020-02-04',
#                '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-08',
#                '2020-02-09', '2020-02-10',
#                ...
#                '2020-06-22', '2020-06-23', '2020-06-24', '2020-06-25',
#                '2020-06-26', '2020-06-27', '2020-06-28', '2020-06-29',
#                '2020-06-30', '2020-07-01'],
#               dtype='datetime64[ns]', length=152, freq='D')

# %%
import matplotlib.pyplot as plt
channel_16 = data.iloc[:, 1:].drop(columns=['Total'])
channel_16.set_index('Date').plot(figsize=(17,10))
#plt.xlabel('Date', fontsize=12, fontweight='bold')
plt.ylabel('Anti-Asian Hate Ratio')
#plt.savefig(r"G:\Youtube\training_model\plot\channel-16.png")
#plt.savefig(r"G:\Youtube\paper\plot-dpi-update\channel-16.png",dpi=300)

# %%
data.iloc[:, 1:]
# Out:
#            Date     Total  Fox News  Breitbart  MSNBC  NBC News  CBS News  \
# 0    2020-01-22  0.000000       NaN        NaN    NaN       NaN       NaN
# 1    2020-01-23  0.166667       NaN        NaN    NaN  0.162791       NaN
# 2    2020-01-24  0.135266       NaN        NaN    NaN  0.152941       NaN
# 3    2020-01-25  0.130719       NaN        NaN    NaN  0.129252       NaN
# 4    2020-01-26  0.130872       NaN        NaN    NaN  0.133106       NaN
# ..          ...       ...       ...        ...    ...       ...       ...
# 322  2020-12-09  0.008065       0.2        NaN    0.0  0.000000       0.0
# 323  2020-12-10  0.000000       0.0        NaN    0.0  0.000000       0.0
# 324  2020-12-11  0.020833       0.0        NaN    0.0  0.000000       NaN
# 325  2020-12-12  0.000000       NaN        NaN    NaN       NaN       NaN
# 326  2020-12-13  0.000000       NaN        NaN    NaN       NaN       NaN
#
#      CNN  NPR  New York Post  USA Today  Los Angeles Times  ABC News  Reuters  \
# ...

# %%
import matplotlib.pyplot as plt
from datetime import datetime

#fig = plt.figure(figsize=(12, 7), dpi = 300)
plt.figure(figsize=(17,12))
total_data['Date'] = pd.to_datetime(total_data.Date, format='%Y-%m-%d')
#plt.title('Time Series Plots for Bitcoin, S&P 500, NASDAQ, and Dow Jones')
#sub.set_title('Anti-asian Index') # non OOP: plt.title('The function f')

bbox_props = dict(boxstyle="round4, pad=0.6", fc="ivory", ec="b", lw=.5)

plt.axvspan(datetime(2020,1,22), datetime(2020,3,1), color='xkcd:sky blue', alpha=0.5, lw=0)
plt.axvspan(datetime(2020,3,1), datetime(2020,6,20), color='xkcd:lightgreen', alpha=0.5, lw=0)
plt.axvspan(datetime(2020,6,20), datetime(2020,9,20), color='xkcd:sky blue', alpha=0.5, lw=0)
plt.axvspan(datetime(2020,9,20), datetime(2020,12,13), color='xkcd:lightgreen', alpha=0.5, lw=0)

plt.plot(total_data['Date'], total_data['Total'], color = 'k')

plt.annotate('', xy=(datetime(2020,1,22), 0.006), xytext=(datetime(2020,3,1), 0.006), xycoords='data', textcoords='data',
            arrowprops={'arrowstyle': '|-|'})
plt.annotate('Phase I', xy=(datetime(2020,2,10), -0.004), ha='center', va='center')

plt.annotate('', xy=(datetime(2020,3,1), 0.006), xytext=(datetime(2020,6,20), 0.006), xycoords='data', textcoords='data',
            arrowprops={'arrowstyle': '|-|'})
plt.annotate('Phase II', xy=(datetime(2020,4,25), -0.004), ha='center', va='center')

plt.annotate('', xy=(datetime(2020,6,20), 0.006), xytext=(datetime(2020,9,20), 0.006), xycoords='data', textcoords='data',
            arrowprops={'arrowstyle': '|-|'})
plt.annotate('Phase III', xy=(datetime(2020,8,5), -0.004), ha='center', va='center')

plt.annotate('', xy=(datetime(2020,9,20), 0.006), xytext=(datetime(2020,12,13), 0.006), xycoords='data', textcoords='data',
            arrowprops={'arrowstyle': '|-|'})
plt.annotate('Phase IV', xy=(datetime(2020,11,1), -0.004), ha='center', va='center')

plt.annotate('U.S. death toll passed 20,000',fontweight='bold',
            xy=(datetime(2020,4,11), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 600), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center', bbox=bbox_props) #center the text horizontally

plt.annotate('Trump tweeted about coronavirus\n using term "Chinese Virus".',fontweight='bold',
            xy=(datetime(2020,3,16), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 550), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center', bbox=bbox_props) #center the text horizontally

plt.annotate('U.S. death toll passeed 70,000. \nConsumer debt hit an all-time high.',fontweight='bold',
            xy=(datetime(2020,5,5), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 500), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center',bbox=bbox_props) #center the text horizontally

#plt.annotate('U.S. death toll passes 100,000. \n38 million jobless claims.',fontweight='bold',
plt.annotate('38 million jobless claimed.',fontweight='bold',
            xy=(datetime(2020,5,22), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 430), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center',bbox=bbox_props) #center the text horizontally

plt.annotate('U.S. reported highest number of COVID-19\n deaths in one day since mid-May.',fontweight='bold',
            xy=(datetime(2020,8,12), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 590), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center',bbox=bbox_props) #center the text horizontally


plt.annotate('Trump and First Lady tested positive for\n Coronavirus. Also, more than a dozen White\n House staff and aides tested positive.',fontweight='bold',
            xy=(datetime(2020,10,2), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 540), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center',bbox=bbox_props) #center the text horizontally

#plt.annotate("U.S. hits record 140,000\n COVID-19 cases per day.",fontweight='bold',
            #xy=(datetime(2020,11,11), 0), #annotate the 50th data point; you could select this in a better way
            #xycoords='data', #the xy we passed refers to the data
            #xytext=(0, 380), #where we put the text relative to the xy
            #textcoords='offset points', #what the xytext coordinates mean
            #arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            #ha='center',bbox=bbox_props) #center the text horizontally

plt.annotate("June 20, Trump held\n a rally in Tulsa, OK.",fontweight='bold',
            xy=(datetime(2020,6,20), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 370), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center',bbox=bbox_props) #center the text horizontally

plt.annotate("August 17, Trump held rallies\n at two regional airpots",fontweight='bold',
            xy=(datetime(2020,8,17), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 505), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center',bbox=bbox_props) #center the text horizontally

plt.annotate("""Trump tweeted “This is\n nobody's fault but China.”.""",fontweight='bold',
            xy=(datetime(2020,9,10), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 470), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center',bbox=bbox_props) #center the text horizontally

plt.annotate('September 13, Trump held\n a rally in Henderson, NV.',fontweight='bold',
            xy=(datetime(2020,9,13), 0), #annotate the 50th data point; you could select this in a better way
            xycoords='data', #the xy we passed refers to the data
            xytext=(0, 420), #where we put the text relative to the xy
            textcoords='offset points', #what the xytext coordinates mean
            arrowprops=dict(arrowstyle="->", linestyle="--", linewidth=2), #style of the arrow
            ha='center',bbox=bbox_props) #center the text horizontally


#plt.xlabel('Date', fontsize=12, fontweight='bold')
plt.xlabel('Date')
#plt.ylabel('Anti-asian Hate Ratio', fontsize=12, fontweight='bold')
plt.ylabel('Anti-asian Hate Ratio')
#plt.savefig(r'G:\Youtube\training_model\plot\time-series-events-3.png')
plt.savefig(r"G:\Youtube\paper\plot-dpi-update\time-series-events.png", dip=300)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dell\anaconda3\lib\site-packages\ipykernel_launcher.py:131: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "dip" which is no longer supported as of 3.3 and will become an error two minor releases later
